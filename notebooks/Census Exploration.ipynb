# %%
import pandas as pd
from safegraph_py_functions import safegraph_py_functions as sgpy
import os
from dotenv import load_dotenv, find_dotenv
from loguru import logger
import zipfile
import tarfile

# %%
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)
os.chdir(os.environ.get("ROOT_DIR"))
from src import DATA_DIR
raw_data_dir = DATA_DIR / 'raw'

# %%
census_path = DATA_DIR / 'raw' / 'open-census-data'
census_archive = census_path / 'safegraph_open_census_data.tar.gz'
census_archive_str = str(census_archive.resolve())
with tarfile.open(census_archive) as tar_ref:
    tar_ref.extractall(census_archive_str[:-7])

# %%
files = [file for file in census_path.glob('**/cbg_b02.csv')]

# %%
df = pd.read_csv(files[0])

# %%
df.head()
# Out:
#    census_block_group  B02001e1  B02001m1  B02001e2  B02001m2  B02001e3  \
# 0         10010201001       745       226       585       198       160
# 1         10010201002      1265       232      1083       222       104
# 2         10010202001       960       261       361       179       568
# 3         10010202002      1236       227       615       154       571
# 4         10010203001      2364       378      1481       314       515
#
#    B02001m3  B02001e4  B02001m4  B02001e5  ...  C02003e15  C02003m15  \
# 0       140         0        11         0  ...          0         11
# 1        75         0        11         9  ...          8         14
# 2       195         0        11         0  ...         18         30
# 3       168         0        11        24  ...          0         11
# 4       197        22        34        27  ...          5         10
#
#    C02003e16  C02003m16  C02003e17  C02003m17  C02003e18  C02003m18  \
# 0          0         11          0         11          0         11
# 1          0         11         21         33          0         11
# 2          0         11          0         11          0         11
# 3          0         11          0         11          0         11
# 4          0         11         56         95          0         11
#
#    C02003e19  C02003m19
# 0          0         11
# 1          0         11
# 2          0         11
# 3          0         11
# 4          0         11
#
# [5 rows x 71 columns]

# %%
set(col[:6] for col in df.columns if col.startswith('B02'))
# Out:
# {'B02001', 'B02008', 'B02009', 'B02010', 'B02011', 'B02012', 'B02013'}

# %%
descriptions = pd.read_csv([file for file in census_path.glob('**/cbg_field_descriptions.csv')][0])

# %%
descriptions[descriptions['table_id'].apply(lambda x: x.startswith('B02001'))]
# Out:
#       table_id                                    field_full_name  \
# 164   B02001e1        RACE: Total: Total population -- (Estimate)
# 165  B02001e10  RACE: Two or more races: Two races excluding S...
# 166   B02001e2  RACE: White alone: Total population -- (Estimate)
# 167   B02001e3  RACE: Black or African American alone: Total p...
# 168   B02001e4  RACE: American Indian and Alaska Native alone:...
# 169   B02001e5  RACE: Asian alone: Total population -- (Estimate)
# 170   B02001e6  RACE: Native Hawaiian and Other Pacific Island...
# 171   B02001e7  RACE: Some other race alone: Total population ...
# 172   B02001e8  RACE: Two or more races: Total population -- (...
# 173   B02001e9  RACE: Two or more races: Two races including S...
# 174   B02001m1  RACE: Total: Total population -- (Margin of Er...
# 175  B02001m10  RACE: Two or more races: Two races excluding S...
# 176   B02001m2  RACE: White alone: Total population -- (Margin...
# 177   B02001m3  RACE: Black or African American alone: Total p...
# 178   B02001m4  RACE: American Indian and Alaska Native alone:...
# 179   B02001m5  RACE: Asian alone: Total population -- (Margin...
# 180   B02001m6  RACE: Native Hawaiian and Other Pacific Island...
# 181   B02001m7  RACE: Some other race alone: Total population ...
# 182   B02001m8  RACE: Two or more races: Total population -- (...
# 183   B02001m9  RACE: Two or more races: Two races including S...
#
#     field_level_1                                      field_level_2  \
# 164          Race                                              Total
# 165          Race                                  Two Or More Races
# 166          Race                                        White Alone
# 167          Race                    Black Or African American Alone
# 168          Race            American Indian And Alaska Native Alone
# 169          Race                                        Asian Alone
# 170          Race   Native Hawaiian And Other Pacific Islander Alone
# 171          Race                              Some Other Race Alone
# 172          Race                                  Two Or More Races
# 173          Race                                  Two Or More Races
# 174          Race                                              Total
# 175          Race                                  Two Or More Races
# 176          Race                                        White Alone
# 177          Race                    Black Or African American Alone
# 178          Race            American Indian And Alaska Native Alone
# 179          Race                                        Asian Alone
# 180          Race   Native Hawaiian And Other Pacific Islander Alone
# 181          Race                              Some Other Race Alone
# 182          Race                                  Two Or More Races
# 183          Race                                  Two Or More Races
#
#                                          field_level_3  \
# 164                     Total Population -- (Estimate)
# 165   Two Races Excluding Some Other Race, And Thre...
# 166                     Total Population -- (Estimate)
# 167                     Total Population -- (Estimate)
# 168                     Total Population -- (Estimate)
# 169                     Total Population -- (Estimate)
# 170                     Total Population -- (Estimate)
# 171                     Total Population -- (Estimate)
# 172                     Total Population -- (Estimate)
# 173                Two Races Including Some Other Race
# 174              Total Population -- (Margin Of Error)
# 175   Two Races Excluding Some Other Race, And Thre...
# 176              Total Population -- (Margin Of Error)
# 177              Total Population -- (Margin Of Error)
# 178              Total Population -- (Margin Of Error)
# 179              Total Population -- (Margin Of Error)
# 180              Total Population -- (Margin Of Error)
# 181              Total Population -- (Margin Of Error)
# 182              Total Population -- (Margin Of Error)
# 183                Two Races Including Some Other Race
#
#                               field_level_4 field_level_5 field_level_6  \
# 164                                     NaN           NaN           NaN
# 165          Total Population -- (Estimate)           NaN           NaN
# 166                                     NaN           NaN           NaN
# 167                                     NaN           NaN           NaN
# 168                                     NaN           NaN           NaN
# 169                                     NaN           NaN           NaN
# 170                                     NaN           NaN           NaN
# 171                                     NaN           NaN           NaN
# 172                                     NaN           NaN           NaN
# 173          Total Population -- (Estimate)           NaN           NaN
# 174                                     NaN           NaN           NaN
# 175   Total Population -- (Margin Of Error)           NaN           NaN
# 176                                     NaN           NaN           NaN
# 177                                     NaN           NaN           NaN
# 178                                     NaN           NaN           NaN
# 179                                     NaN           NaN           NaN
# 180                                     NaN           NaN           NaN
# 181                                     NaN           NaN           NaN
# 182                                     NaN           NaN           NaN
# 183   Total Population -- (Margin Of Error)           NaN           NaN
#
#     field_level_7 field_level_8
# 164           NaN           NaN
# 165           NaN           NaN
# 166           NaN           NaN
# 167           NaN           NaN
# 168           NaN           NaN
# 169           NaN           NaN
# 170           NaN           NaN
# 171           NaN           NaN
# 172           NaN           NaN
# 173           NaN           NaN
# 174           NaN           NaN
# 175           NaN           NaN
# 176           NaN           NaN
# 177           NaN           NaN
# 178           NaN           NaN
# 179           NaN           NaN
# 180           NaN           NaN
# 181           NaN           NaN
# 182           NaN           NaN
# 183           NaN           NaN
